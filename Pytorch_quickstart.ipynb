# %%
import torch
from torch import nn
from torch.utils.data import DataLoader #데이터 로더
from torchvision import datasets #데이터셋 (real-world vision data like CIFAR, COCO)
from torchvision.transforms import ToTensor
#Every TorchVision Dataset includes two arguments: 
#transform and target_transform to modify the samples and labels respectively.

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)
# Out:
# ...
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# ...
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
b_size = 64

#data loader 만들기

train_dataloader = DataLoader(training_data, batch_size = b_size)
test_dataloader = DataLoader(test_data, batch_size = b_size)

# %%
for X, y in test_dataloader:
  print(f"Shape of X [N,C,H,W]: {X.shape}")
  print(f"Shape of y [N,C,H,W]: {y.shape}")
# Out:
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# Shape of y [N,C,H,W]: torch.Size([64])
# Shape of X [N,C,H,W]: torch.Size([64, 1, 28, 28])
# ...

# %%
import matplotlib.pyplot as plt

# %%
training_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

# %%
figure = plt.figure(figsize=(8,8))
cols,rows = 8,8

for i in range(1,col*row+1):
  sample_idx = torch.randint(len(training_data), size=(1,)).item()
  img, label = training_data[sample_idx]
  figure.add_subplot(rows,cols,i)
  plt.title(labels_map[label])
  plt.axis('off')
  plt.imshow(img.squeeze(), cmap='gray')
plt.show()
